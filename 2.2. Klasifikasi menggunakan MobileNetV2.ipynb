# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, classification_report

# Set seed
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
tf.keras.utils.set_random_seed(seed)

# %%
# Mount GDRIVE jika menggunakan Google Collab
# from google.colab import drive
# drive.mount('/content/drive')

# PATH = '/content/drive/MyDrive/'

# Jika tidak menggunakan google collab
PATH = ''

# %% [markdown]
# ## Read Data

# %%
train_data = pd.read_csv(PATH + 'train.csv')
val_data   = pd.read_csv(PATH + 'validation.csv')
test_data  = pd.read_csv(PATH + 'test.csv')

# %%
print('Data Training:')
train_data
# Out:
# Data Training:
#                                              image_path        label
# 0     augmented_images\Lidah Buaya\rotated_Lidah bua...  Lidah Buaya
# 1      augmented_images\Pepaya\brightness_Pepaya138.jpg       Pepaya
# 2     Indonesian Herb Leaf Dataset 3500/Jeruk Nipis\...  Jeruk Nipis
# 3     augmented_images\Jambu Biji\brightness_Jambu b...   Jambu Biji
# 4     augmented_images\Lidah Buaya\brightness_Lidah ...  Lidah Buaya
# ...                                                 ...          ...
# 3995       augmented_images\Pandan\fliped_Pandan254.jpg       Pandan
# 3996  Indonesian Herb Leaf Dataset 3500/Jambu Biji\J...   Jambu Biji
# 3997  Indonesian Herb Leaf Dataset 3500/Seledri\Sele...      Seledri
# 3998  augmented_images\Jambu Biji\fliped_Jambu biji2...   Jambu Biji
# 3999  Indonesian Herb Leaf Dataset 3500/Jeruk Nipis\...  Jeruk Nipis
#
# [4000 rows x 2 columns]

# %%
print('Data Validation:')
val_data
# Out:
# Data Validation:
#                                             image_path            label
# 0    augmented_images\Jambu Biji\brightness_Jambu b...       Jambu Biji
# 1    Indonesian Herb Leaf Dataset 3500/Jeruk Nipis\...      Jeruk Nipis
# 2    Indonesian Herb Leaf Dataset 3500/Pepaya\Pepay...           Pepaya
# 3    Indonesian Herb Leaf Dataset 3500/Jeruk Nipis\...      Jeruk Nipis
# 4    Indonesian Herb Leaf Dataset 3500/Sirih\Sirih0...            Sirih
# ..                                                 ...              ...
# 495  Indonesian Herb Leaf Dataset 3500/Belimbing Wu...  Belimbing Wuluh
# 496  Indonesian Herb Leaf Dataset 3500/Lidah Buaya\...      Lidah Buaya
# 497  Indonesian Herb Leaf Dataset 3500/Belimbing Wu...  Belimbing Wuluh
# 498  Indonesian Herb Leaf Dataset 3500/Nangka\Nangk...           Nangka
# 499  Indonesian Herb Leaf Dataset 3500/Pepaya\Pepay...           Pepaya
#
# [500 rows x 2 columns]

# %%
print('Data Testing:')
test_data
# Out:
# Data Testing:
#                                             image_path            label
# 0    Indonesian Herb Leaf Dataset 3500/Seledri\Sele...          Seledri
# 1    Indonesian Herb Leaf Dataset 3500/Sirih\Sirih3...            Sirih
# 2    Indonesian Herb Leaf Dataset 3500/Pepaya\Pepay...           Pepaya
# 3    Indonesian Herb Leaf Dataset 3500/Lidah Buaya\...      Lidah Buaya
# 4    Indonesian Herb Leaf Dataset 3500/Belimbing Wu...  Belimbing Wuluh
# ..                                                 ...              ...
# 495  Indonesian Herb Leaf Dataset 3500/Jeruk Nipis\...      Jeruk Nipis
# 496  Indonesian Herb Leaf Dataset 3500/Jambu Biji\J...       Jambu Biji
# 497  Indonesian Herb Leaf Dataset 3500/Sirih\Sirih1...            Sirih
# 498  Indonesian Herb Leaf Dataset 3500/Seledri\Sele...          Seledri
# 499  Indonesian Herb Leaf Dataset 3500/Pandan\Panda...           Pandan
#
# [500 rows x 2 columns]

# %%
size       = 224
batch_size = 32
class_mode = 'categorical'

# Data preprocessing
datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_dataframe(
    train_data,
    x_col='image_path',
    y_col='label',
    target_size=(size, size),
    batch_size=batch_size,
    class_mode=class_mode,
    color_mode="rgb",
    shuffle=False

)

validation_generator = datagen.flow_from_dataframe(
    val_data,
    x_col='image_path',
    y_col='label',
    target_size=(size, size),
    batch_size=batch_size,
    class_mode=class_mode,
    color_mode="rgb",
    shuffle=False
)

test_generator = datagen.flow_from_dataframe(
    test_data,
    x_col='image_path',
    y_col='label',
    target_size=(size, size),
    batch_size=batch_size,
    class_mode=class_mode,
    color_mode="rgb",
    shuffle=False
)
# Out:
# Found 4000 validated image filenames belonging to 10 classes.
# Found 500 validated image filenames belonging to 10 classes.
# Found 500 validated image filenames belonging to 10 classes.

# %% [markdown]
# ## MobileNetV2

# %% [markdown]
# https://blog.roboflow.com/how-to-train-mobilenetv2-on-a-custom-dataset/

# %%
# Load MobileNetV2 with pretrained weights and exclude the top layers
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(size, size, 3))

# Freeze the base model layers to prevent them from being trained
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of MobileNetV2
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)  # Add a fully connected layer
x = Dropout(0.5)(x)
# x = Dense(512, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)  # Output layer with softmax activation

# Create the full model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_path = 'best_model_MobileNetV2.keras'

callbacks= [ModelCheckpoint(model_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max'),
           EarlyStopping(monitor='val_accuracy', patience=20, verbose=1)] 

history = model.fit(train_generator,
                    epochs=100,
                    validation_data = validation_generator,
                    batch_size=32,
                    callbacks = callbacks)
# Out:
# Epoch 1/100
# 125/125 [==============================] - ETA: 0s - loss: 0.4747 - accuracy: 0.8380
# Epoch 1: val_accuracy improved from -inf to 0.90800, saving model to best_model_MobileNetV2.keras
# 125/125 [==============================] - 75s 579ms/step - loss: 0.4747 - accuracy: 0.8380 - val_loss: 0.2540 - val_accuracy: 0.9080
# Epoch 2/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.9420
# Epoch 2: val_accuracy improved from 0.90800 to 0.95600, saving model to best_model_MobileNetV2.keras
# 125/125 [==============================] - 72s 575ms/step - loss: 0.1790 - accuracy: 0.9420 - val_loss: 0.1539 - val_accuracy: 0.9560
# Epoch 3/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9510
# Epoch 3: val_accuracy did not improve from 0.95600
# 125/125 [==============================] - 72s 571ms/step - loss: 0.1454 - accuracy: 0.9510 - val_loss: 0.1689 - val_accuracy: 0.9460
# Epoch 4/100
# 125/125 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9607
# Epoch 4: val_accuracy did not improve from 0.95600
# 125/125 [==============================] - 73s 585ms/step - loss: 0.1197 - accuracy: 0.9607 - val_loss: 0.1466 - val_accuracy: 0.9560
# Epoch 5/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9672
# Epoch 5: val_accuracy improved from 0.95600 to 0.96400, saving model to best_model_MobileNetV2.keras
# 125/125 [==============================] - 75s 597ms/step - loss: 0.0938 - accuracy: 0.9672 - val_loss: 0.1117 - val_accuracy: 0.9640
# Epoch 6/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9750
# Epoch 6: val_accuracy did not improve from 0.96400
# 125/125 [==============================] - 74s 594ms/step - loss: 0.0759 - accuracy: 0.9750 - val_loss: 0.1484 - val_accuracy: 0.9520
# Epoch 7/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9778
# Epoch 7: val_accuracy improved from 0.96400 to 0.97400, saving model to best_model_MobileNetV2.keras
# 125/125 [==============================] - 73s 580ms/step - loss: 0.0654 - accuracy: 0.9778 - val_loss: 0.0829 - val_accuracy: 0.9740
# Epoch 8/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9775
# Epoch 8: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 582ms/step - loss: 0.0595 - accuracy: 0.9775 - val_loss: 0.0944 - val_accuracy: 0.9720
# Epoch 9/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9793
# Epoch 9: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 586ms/step - loss: 0.0583 - accuracy: 0.9793 - val_loss: 0.0885 - val_accuracy: 0.9740
# Epoch 10/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9737
# Epoch 10: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 74s 588ms/step - loss: 0.0749 - accuracy: 0.9737 - val_loss: 0.1189 - val_accuracy: 0.9700
# Epoch 11/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9768
# Epoch 11: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 72s 578ms/step - loss: 0.0751 - accuracy: 0.9768 - val_loss: 0.0921 - val_accuracy: 0.9720
# Epoch 12/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9845
# Epoch 12: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 582ms/step - loss: 0.0481 - accuracy: 0.9845 - val_loss: 0.0916 - val_accuracy: 0.9740
# Epoch 13/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9868
# Epoch 13: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 72s 576ms/step - loss: 0.0428 - accuracy: 0.9868 - val_loss: 0.0849 - val_accuracy: 0.9740
# Epoch 14/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9870
# Epoch 14: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 581ms/step - loss: 0.0458 - accuracy: 0.9870 - val_loss: 0.1079 - val_accuracy: 0.9680
# Epoch 15/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9822
# Epoch 15: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 72s 579ms/step - loss: 0.0545 - accuracy: 0.9822 - val_loss: 0.0982 - val_accuracy: 0.9680
# Epoch 16/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9815
# Epoch 16: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 580ms/step - loss: 0.0527 - accuracy: 0.9815 - val_loss: 0.1187 - val_accuracy: 0.9720
# Epoch 17/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9885
# Epoch 17: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 585ms/step - loss: 0.0368 - accuracy: 0.9885 - val_loss: 0.0927 - val_accuracy: 0.9660
# Epoch 18/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9908
# Epoch 18: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 587ms/step - loss: 0.0314 - accuracy: 0.9908 - val_loss: 0.1098 - val_accuracy: 0.9660
# Epoch 19/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9847
# Epoch 19: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 74s 589ms/step - loss: 0.0460 - accuracy: 0.9847 - val_loss: 0.1141 - val_accuracy: 0.9720
# Epoch 20/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9785
# Epoch 20: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 72s 574ms/step - loss: 0.0661 - accuracy: 0.9785 - val_loss: 0.1365 - val_accuracy: 0.9660
# Epoch 21/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9855
# Epoch 21: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 587ms/step - loss: 0.0444 - accuracy: 0.9855 - val_loss: 0.1721 - val_accuracy: 0.9680
# Epoch 22/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9893
# Epoch 22: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 71s 569ms/step - loss: 0.0346 - accuracy: 0.9893 - val_loss: 0.1277 - val_accuracy: 0.9720
# Epoch 23/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9837
# Epoch 23: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 72s 573ms/step - loss: 0.0455 - accuracy: 0.9837 - val_loss: 0.1338 - val_accuracy: 0.9660
# Epoch 24/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9887
# Epoch 24: val_accuracy did not improve from 0.97400
# 125/125 [==============================] - 73s 585ms/step - loss: 0.0319 - accuracy: 0.9887 - val_loss: 0.1688 - val_accuracy: 0.9600
# Epoch 25/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9855
# Epoch 25: val_accuracy improved from 0.97400 to 0.97600, saving model to best_model_MobileNetV2.keras
# 125/125 [==============================] - 73s 587ms/step - loss: 0.0404 - accuracy: 0.9855 - val_loss: 0.1322 - val_accuracy: 0.9760
# Epoch 26/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9810
# Epoch 26: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 582ms/step - loss: 0.0547 - accuracy: 0.9810 - val_loss: 0.1264 - val_accuracy: 0.9760
# Epoch 27/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9875
# Epoch 27: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 582ms/step - loss: 0.0390 - accuracy: 0.9875 - val_loss: 0.2544 - val_accuracy: 0.9560
# Epoch 28/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9760
# Epoch 28: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 72s 575ms/step - loss: 0.0931 - accuracy: 0.9760 - val_loss: 0.2180 - val_accuracy: 0.9620
# Epoch 29/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9900
# Epoch 29: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 586ms/step - loss: 0.0346 - accuracy: 0.9900 - val_loss: 0.2040 - val_accuracy: 0.9640
# Epoch 30/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9895
# Epoch 30: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 580ms/step - loss: 0.0345 - accuracy: 0.9895 - val_loss: 0.1338 - val_accuracy: 0.9740
# Epoch 31/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9910
# Epoch 31: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 582ms/step - loss: 0.0317 - accuracy: 0.9910 - val_loss: 0.2026 - val_accuracy: 0.9600
# Epoch 32/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9865
# Epoch 32: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 585ms/step - loss: 0.0490 - accuracy: 0.9865 - val_loss: 0.1388 - val_accuracy: 0.9740
# Epoch 33/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9900
# Epoch 33: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 74s 589ms/step - loss: 0.0463 - accuracy: 0.9900 - val_loss: 0.1151 - val_accuracy: 0.9680
# Epoch 34/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9935
# Epoch 34: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 76s 610ms/step - loss: 0.0237 - accuracy: 0.9935 - val_loss: 0.1531 - val_accuracy: 0.9700
# Epoch 35/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9920
# Epoch 35: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 74s 592ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.1620 - val_accuracy: 0.9640
# Epoch 36/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9908
# Epoch 36: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 74s 592ms/step - loss: 0.0280 - accuracy: 0.9908 - val_loss: 0.1596 - val_accuracy: 0.9700
# Epoch 37/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9935
# Epoch 37: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 74s 592ms/step - loss: 0.0226 - accuracy: 0.9935 - val_loss: 0.1285 - val_accuracy: 0.9720
# Epoch 38/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9935
# Epoch 38: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 74s 593ms/step - loss: 0.0171 - accuracy: 0.9935 - val_loss: 0.1403 - val_accuracy: 0.9740
# Epoch 39/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9895
# Epoch 39: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 74s 594ms/step - loss: 0.0352 - accuracy: 0.9895 - val_loss: 0.2247 - val_accuracy: 0.9660
# Epoch 40/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9883
# Epoch 40: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 74s 592ms/step - loss: 0.0311 - accuracy: 0.9883 - val_loss: 0.2242 - val_accuracy: 0.9680
# Epoch 41/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9887
# Epoch 41: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 584ms/step - loss: 0.0407 - accuracy: 0.9887 - val_loss: 0.1842 - val_accuracy: 0.9680
# Epoch 42/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9895
# Epoch 42: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 72s 579ms/step - loss: 0.0343 - accuracy: 0.9895 - val_loss: 0.2067 - val_accuracy: 0.9640
# Epoch 43/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9880
# Epoch 43: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 581ms/step - loss: 0.0505 - accuracy: 0.9880 - val_loss: 0.1937 - val_accuracy: 0.9680
# Epoch 44/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9885
# Epoch 44: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 583ms/step - loss: 0.0489 - accuracy: 0.9885 - val_loss: 0.2150 - val_accuracy: 0.9680
# Epoch 45/100
# 125/125 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9920
# Epoch 45: val_accuracy did not improve from 0.97600
# 125/125 [==============================] - 73s 582ms/step - loss: 0.0330 - accuracy: 0.9920 - val_loss: 0.1293 - val_accuracy: 0.9760
# Epoch 45: early stopping

# %%
plt.figure(figsize=(6,4))
plt.title('Accuracy scores')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

plt.figure(figsize=(6,4))
plt.title('Loss value')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

# %% [markdown]
# ## Model Evaluate

# %%
model_path = 'best_model_MobileNetV2.keras'

n_model = load_model(model_path) # Memuat model yang sudah disimpan

# %%
predictions = n_model.predict(test_generator)
y_pred      = np.argmax(predictions, axis=1)
# Out:
# 16/16 [==============================] - 9s 489ms/step

# %%
Confusion_matrix = confusion_matrix(test_generator.classes, y_pred)
class_label      = test_generator.class_indices.keys()
df_confusion     = pd.DataFrame(Confusion_matrix, index = class_label, columns = class_label)

sns.heatmap(df_confusion, annot=True, fmt = "d", cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.xlabel('Prediction Label')
plt.ylabel('Actual Label')
plt.show()

# %%
_accuracy   = round(accuracy_score(test_generator.classes, y_pred)*100, 2)
_precission = round(precision_score(test_generator.classes, y_pred, average='weighted')*100, 2)
_recall     = round(recall_score(test_generator.classes, y_pred, average='weighted')*100, 2)
_fscore     = round(f1_score(test_generator.classes, y_pred, average='weighted')*100, 2)

print('Accuracy   :', _accuracy, '%')
print('Precission :', _precission, '%')
print('Recall     :', _recall, '%')
print('F-Score    :', _fscore, '%')
# Out:
# Accuracy   : 96.6 %
# Precission : 96.73 %
# Recall     : 96.6 %
# F-Score    : 96.6 %

# %%
# Ambil nama kelas
class_labels = list(test_generator.class_indices.keys())

print(classification_report(test_generator.classes, y_pred, target_names=class_labels, digits=4))
# Out:
#                  precision    recall  f1-score   support
#
# Belimbing Wuluh     0.8833    0.9636    0.9217        55
#      Jambu Biji     1.0000    0.9231    0.9600        52
#     Jeruk Nipis     0.9608    0.9800    0.9703        50
#         Kemangi     0.9592    0.8868    0.9216        53
#     Lidah Buaya     0.9623    1.0000    0.9808        51
#          Nangka     0.9500    1.0000    0.9744        38
#          Pandan     1.0000    0.9574    0.9783        47
#          Pepaya     1.0000    1.0000    1.0000        49
#         Seledri     1.0000    0.9804    0.9901        51
#           Sirih     0.9636    0.9815    0.9725        54
#
#        accuracy                         0.9660       500
#       macro avg     0.9679    0.9673    0.9670       500
#    weighted avg     0.9673    0.9660    0.9660       500
